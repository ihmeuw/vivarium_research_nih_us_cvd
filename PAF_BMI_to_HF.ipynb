# %% [markdown]
# # Heart Failure PAF Calculations
#
# This workbook is designed to find the PAF for BMI to heart failure ONLY while NOT considering risk correlation to mediation. The more complex versiont that includes these considerations is in another workbook.

# %%
from vivarium import InteractiveContext, Artifact

from datetime import datetime, timedelta
from pathlib import Path
import itertools
import matplotlib.pyplot as plt
import ipywidgets
import pandas as pd, numpy as np
pd.set_option('display.max_rows', 60)
import seaborn as sns

import numpy as np
import researchpy as rp
import statsmodels.api as sm
import statsmodels.formula.api as smf
from matplotlib.backends.backend_pdf import PdfPages
import scipy.stats
from typing import List, Tuple, Union
import scipy.stats as sp

# %%
path = Path('/ihme/homes/lutzes/vivarium_nih_us_cvd/src/vivarium_nih_us_cvd/model_specifications/nih_us_cvd.yaml')

# %%
sim = InteractiveContext(Path(path), setup=False)
sim.configuration.update({
                          'population':
                              {'population_size': 10_000,
                              },
                          'time':
                              {'start':
                                  {'year': 2021
                                  }
                              }
                          }
                        )
sim.setup()
# Out:
# 2023-01-17 13:47:03.084 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering metrics.1.population_manager.metrics as modifier to metrics
# 2023-01-17 13:47:03.179 | DEBUG    | vivarium.framework.artifact.manager:_load_artifact:66 - Running simulation from artifact located at /ihme/costeffectiveness/artifacts/vivarium_nih_us_cvd/alabama.hdf.
# 2023-01-17 13:47:03.182 | DEBUG    | vivarium.framework.artifact.manager:_load_artifact:67 - Artifact base filter terms are ['draw == 0'].
# 2023-01-17 13:47:03.185 | DEBUG    | vivarium.framework.artifact.manager:_load_artifact:68 - Artifact additional filter terms are None.
# 2023-01-17 13:47:03.541 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline cause_specific_mortality_rate
# 2023-01-17 13:47:03.542 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline mortality_rate
# 2023-01-17 13:47:03.896 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline affected_unmodeled.cause_specific_mortality_rate
# 2023-01-17 13:47:03.897 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline affected_unmodeled.cause_specific_mortality_rate.paf
# 2023-01-17 13:47:03.898 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering metrics.2.mortality_observer.metrics as modifier to metrics
# 2023-01-17 13:47:03.898 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline disability_weight
# 2023-01-17 13:47:03.899 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering metrics.3.disability_observer.metrics as modifier to metrics
# 2023-01-17 13:47:03.900 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering metrics.4.disease_observer.ischemic_stroke.metrics as modifier to metrics
# 2023-01-17 13:47:03.900 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering metrics.5.disease_observer.myocardial_infarction.metrics as modifier to metrics
# 2023-01-17 13:47:03.901 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline sbp_medication_adherence.propensity
# 2023-01-17 13:47:03.901 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline sbp_medication_adherence.exposure
# 2023-01-17 13:47:04.216 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline risk_factor.sbp_medication_adherence.exposure_parameters
# 2023-01-17 13:47:04.217 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline ldlc_medication_adherence.propensity
# 2023-01-17 13:47:04.218 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline ldlc_medication_adherence.exposure
# 2023-01-17 13:47:04.552 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline risk_factor.ldlc_medication_adherence.exposure_parameters
# 2023-01-17 13:47:04.553 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline outreach.propensity
# 2023-01-17 13:47:04.554 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline outreach.exposure
# 2023-01-17 13:47:04.732 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline risk_factor.outreach.exposure_parameters
# 2023-01-17 13:47:04.733 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline risk_factor.outreach.exposure_parameters.paf
# 2023-01-17 13:47:04.734 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline polypill.propensity
# 2023-01-17 13:47:04.734 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline polypill.exposure
# 2023-01-17 13:47:04.843 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline risk_factor.polypill.exposure_parameters
# 2023-01-17 13:47:04.843 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline risk_factor.polypill.exposure_parameters.paf
# 2023-01-17 13:47:05.932 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering acute_myocardial_infarction.incidence_rate.1.adjust_target as modifier to acute_myocardial_infarction.incidence_rate
# 2023-01-17 13:47:05.932 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering acute_myocardial_infarction.incidence_rate.paf.1.lookup_table_12 as modifier to acute_myocardial_infarction.incidence_rate.paf
# 2023-01-17 13:47:06.140 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering post_myocardial_infarction_to_acute_myocardial_infarction.transition_rate.1.adjust_target as modifier to post_myocardial_infarction_to_acute_myocardial_infarction.transition_rate
# 2023-01-17 13:47:06.141 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering post_myocardial_infarction_to_acute_myocardial_infarction.transition_rate.paf.1.lookup_table_14 as modifier to post_myocardial_infarction_to_acute_myocardial_infarction.transition_rate.paf
# 2023-01-17 13:47:06.345 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering acute_ischemic_stroke.incidence_rate.1.adjust_target as modifier to acute_ischemic_stroke.incidence_rate
# 2023-01-17 13:47:06.345 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering acute_ischemic_stroke.incidence_rate.paf.1.lookup_table_16 as modifier to acute_ischemic_stroke.incidence_rate.paf
# 2023-01-17 13:47:06.544 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering chronic_ischemic_stroke_to_acute_ischemic_stroke.transition_rate.1.adjust_target as modifier to chronic_ischemic_stroke_to_acute_ischemic_stroke.transition_rate
# 2023-01-17 13:47:06.544 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering chronic_ischemic_stroke_to_acute_ischemic_stroke.transition_rate.paf.1.lookup_table_18 as modifier to chronic_ischemic_stroke_to_acute_ischemic_stroke.transition_rate.paf
# 2023-01-17 13:47:07.509 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering acute_myocardial_infarction.incidence_rate.2.adjust_target as modifier to acute_myocardial_infarction.incidence_rate
# 2023-01-17 13:47:07.512 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering acute_myocardial_infarction.incidence_rate.paf.2.lookup_table_20 as modifier to acute_myocardial_infarction.incidence_rate.paf
# 2023-01-17 13:47:07.723 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering post_myocardial_infarction_to_acute_myocardial_infarction.transition_rate.2.adjust_target as modifier to post_myocardial_infarction_to_acute_myocardial_infarction.transition_rate
# 2023-01-17 13:47:07.724 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering post_myocardial_infarction_to_acute_myocardial_infarction.transition_rate.paf.2.lookup_table_22 as modifier to post_myocardial_infarction_to_acute_myocardial_infarction.transition_rate.paf
# 2023-01-17 13:47:07.927 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering acute_ischemic_stroke.incidence_rate.2.adjust_target as modifier to acute_ischemic_stroke.incidence_rate
# 2023-01-17 13:47:07.927 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering acute_ischemic_stroke.incidence_rate.paf.2.lookup_table_24 as modifier to acute_ischemic_stroke.incidence_rate.paf
# 2023-01-17 13:47:08.126 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering chronic_ischemic_stroke_to_acute_ischemic_stroke.transition_rate.2.adjust_target as modifier to chronic_ischemic_stroke_to_acute_ischemic_stroke.transition_rate
# 2023-01-17 13:47:08.127 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering chronic_ischemic_stroke_to_acute_ischemic_stroke.transition_rate.paf.2.lookup_table_26 as modifier to chronic_ischemic_stroke_to_acute_ischemic_stroke.transition_rate.paf
# 2023-01-17 13:47:09.170 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering acute_myocardial_infarction.incidence_rate.3.adjust_target as modifier to acute_myocardial_infarction.incidence_rate
# 2023-01-17 13:47:09.174 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering acute_myocardial_infarction.incidence_rate.paf.3.lookup_table_28 as modifier to acute_myocardial_infarction.incidence_rate.paf
# 2023-01-17 13:47:09.392 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering post_myocardial_infarction_to_acute_myocardial_infarction.transition_rate.3.adjust_target as modifier to post_myocardial_infarction_to_acute_myocardial_infarction.transition_rate
# 2023-01-17 13:47:09.393 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering post_myocardial_infarction_to_acute_myocardial_infarction.transition_rate.paf.3.lookup_table_30 as modifier to post_myocardial_infarction_to_acute_myocardial_infarction.transition_rate.paf
# 2023-01-17 13:47:09.597 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering acute_ischemic_stroke.incidence_rate.3.adjust_target as modifier to acute_ischemic_stroke.incidence_rate
# 2023-01-17 13:47:09.598 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering acute_ischemic_stroke.incidence_rate.paf.3.lookup_table_32 as modifier to acute_ischemic_stroke.incidence_rate.paf
# 2023-01-17 13:47:09.804 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering chronic_ischemic_stroke_to_acute_ischemic_stroke.transition_rate.3.adjust_target as modifier to chronic_ischemic_stroke_to_acute_ischemic_stroke.transition_rate
# 2023-01-17 13:47:09.805 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering chronic_ischemic_stroke_to_acute_ischemic_stroke.transition_rate.paf.3.lookup_table_34 as modifier to chronic_ischemic_stroke_to_acute_ischemic_stroke.transition_rate.paf
# 2023-01-17 13:47:10.342 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering cause_specific_mortality_rate.1.disease_model.ischemic_stroke.adjust_cause_specific_mortality_rate as modifier to cause_specific_mortality_rate
# 2023-01-17 13:47:10.709 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline acute_ischemic_stroke.incidence_rate
# 2023-01-17 13:47:10.710 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline acute_ischemic_stroke.incidence_rate.paf
# 2023-01-17 13:47:10.958 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline acute_ischemic_stroke.dwell_time
# 2023-01-17 13:47:11.202 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline acute_ischemic_stroke.disability_weight
# 2023-01-17 13:47:11.203 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering disability_weight.1.acute_ischemic_stroke.disability_weight as modifier to disability_weight
# 2023-01-17 13:47:11.446 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline acute_ischemic_stroke.excess_mortality_rate
# 2023-01-17 13:47:11.447 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline acute_ischemic_stroke.excess_mortality_rate.paf
# 2023-01-17 13:47:11.447 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering mortality_rate.1.diseasestate.acute_ischemic_stroke.adjust_mortality_rate as modifier to mortality_rate
# 2023-01-17 13:47:11.691 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline chronic_ischemic_stroke.dwell_time
# 2023-01-17 13:47:11.926 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline chronic_ischemic_stroke.disability_weight
# 2023-01-17 13:47:11.927 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering disability_weight.2.chronic_ischemic_stroke.disability_weight as modifier to disability_weight
# 2023-01-17 13:47:12.162 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline chronic_ischemic_stroke.excess_mortality_rate
# 2023-01-17 13:47:12.163 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline chronic_ischemic_stroke.excess_mortality_rate.paf
# 2023-01-17 13:47:12.166 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering mortality_rate.2.diseasestate.chronic_ischemic_stroke.adjust_mortality_rate as modifier to mortality_rate
# 2023-01-17 13:47:12.285 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline chronic_ischemic_stroke_to_acute_ischemic_stroke.transition_rate
# 2023-01-17 13:47:12.286 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline chronic_ischemic_stroke_to_acute_ischemic_stroke.transition_rate.paf
# 2023-01-17 13:47:12.735 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering cause_specific_mortality_rate.2.disease_model.myocardial_infarction.adjust_cause_specific_mortality_rate as modifier to cause_specific_mortality_rate
# 2023-01-17 13:47:13.002 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline acute_myocardial_infarction.incidence_rate
# 2023-01-17 13:47:13.003 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline acute_myocardial_infarction.incidence_rate.paf
# 2023-01-17 13:47:13.225 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline acute_myocardial_infarction.dwell_time
# 2023-01-17 13:47:13.530 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline acute_myocardial_infarction.disability_weight
# 2023-01-17 13:47:13.530 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering disability_weight.3.acute_myocardial_infarction.disability_weight as modifier to disability_weight
# 2023-01-17 13:47:13.870 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline acute_myocardial_infarction.excess_mortality_rate
# 2023-01-17 13:47:13.871 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline acute_myocardial_infarction.excess_mortality_rate.paf
# 2023-01-17 13:47:13.871 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering mortality_rate.3.diseasestate.acute_myocardial_infarction.adjust_mortality_rate as modifier to mortality_rate
# 2023-01-17 13:47:14.084 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline post_myocardial_infarction.dwell_time
# 2023-01-17 13:47:14.265 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline post_myocardial_infarction.disability_weight
# 2023-01-17 13:47:14.266 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering disability_weight.4.post_myocardial_infarction.disability_weight as modifier to disability_weight
# 2023-01-17 13:47:14.600 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline post_myocardial_infarction.excess_mortality_rate
# 2023-01-17 13:47:14.601 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline post_myocardial_infarction.excess_mortality_rate.paf
# 2023-01-17 13:47:14.602 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering mortality_rate.4.diseasestate.post_myocardial_infarction.adjust_mortality_rate as modifier to mortality_rate
# 2023-01-17 13:47:14.699 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline post_myocardial_infarction_to_acute_myocardial_infarction.transition_rate
# 2023-01-17 13:47:14.699 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline post_myocardial_infarction_to_acute_myocardial_infarction.transition_rate.paf
# 2023-01-17 13:47:14.700 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline high_ldl_cholesterol.propensity
# 2023-01-17 13:47:14.701 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline high_ldl_cholesterol.exposure
# 2023-01-17 13:47:14.701 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline high_ldl_cholesterol.gbd_exposure
# 2023-01-17 13:47:23.553 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering metrics.6.continuous_risk_observer.risk_factor.high_ldl_cholesterol.metrics as modifier to metrics
# 2023-01-17 13:47:23.555 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline high_systolic_blood_pressure.propensity
# 2023-01-17 13:47:23.555 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline high_systolic_blood_pressure.exposure
# 2023-01-17 13:47:23.556 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline high_systolic_blood_pressure.gbd_exposure
# 2023-01-17 13:47:38.695 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering metrics.7.continuous_risk_observer.risk_factor.high_systolic_blood_pressure.metrics as modifier to metrics
# 2023-01-17 13:47:38.697 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline high_body_mass_index_in_adults.propensity
# 2023-01-17 13:47:38.697 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline high_body_mass_index_in_adults.exposure
# 2023-01-17 13:47:38.699 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline high_body_mass_index_in_adults.gbd_exposure
# 2023-01-17 13:47:52.952 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering metrics.8.continuous_risk_observer.risk_factor.high_body_mass_index_in_adults.metrics as modifier to metrics
# 2023-01-17 13:47:53.185 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline utilization_rate
# 2023-01-17 13:47:53.226 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering high_systolic_blood_pressure.exposure.1.adjust_target as modifier to high_systolic_blood_pressure.exposure
# 2023-01-17 13:47:53.227 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering high_ldl_cholesterol.exposure.1.adjust_target as modifier to high_ldl_cholesterol.exposure
# 2023-01-17 13:47:53.228 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering metrics.9.healthcare_visit_observer.metrics as modifier to metrics
# 2023-01-17 13:47:53.229 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering metrics.10.person_time_observer.sbp_medication.metrics as modifier to metrics
# 2023-01-17 13:47:53.230 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering metrics.11.person_time_observer.ldlc_medication.metrics as modifier to metrics
# 2023-01-17 13:47:53.231 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering risk_factor.outreach.exposure_parameters.1.outreach_intervention._coverage_effect as modifier to risk_factor.outreach.exposure_parameters
# 2023-01-17 13:47:53.232 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering risk_factor.polypill.exposure_parameters.1.polypill_intervention._coverage_effect as modifier to risk_factor.polypill.exposure_parameters
# 2023-01-17 13:47:53.232 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering metrics.12.person_time_observer.outreach.metrics as modifier to metrics
# 2023-01-17 13:47:53.233 | DEBUG    | vivarium.framework.values:register_value_modifier:392 - Registering metrics.13.person_time_observer.polypill.metrics as modifier to metrics
# 2023-01-17 13:47:53.234 | DEBUG    | vivarium.framework.values:_register_value_producer:338 - Registering value pipeline metrics
# 2023-01-17 13:47:53.238 | WARNING  | vivarium.framework.resource:_to_graph:253 - Resource column.None is not provided by any component but is needed to compute (value_source.high_body_mass_index_in_adults.exposure).

# %%
pop0 = sim.get_population()
pop0.head()
# Out:
#    tracked location     sex  alive entrance_time        age exit_time  \
# 0     True  Alabama  Female  alive    2020-12-04  47.388882       NaT
# 1     True  Alabama    Male  alive    2020-12-04  41.564194       NaT
# 2     True  Alabama  Female  alive    2020-12-04  53.155826       NaT
# 3     True  Alabama    Male  alive    2020-12-04  30.457692       NaT
# 4     True  Alabama  Female  alive    2020-12-04  19.554806       NaT
#
#    years_of_life_lost cause_of_death  years_lived_with_disability  ...  \
# 0                 0.0       not_dead                          0.0  ...
# 1                 0.0       not_dead                          0.0  ...
# 2                 0.0       not_dead                          0.0  ...
# 3                 0.0       not_dead                          0.0  ...
# 4                 0.0       not_dead                          0.0  ...
#
#   outreach               sbp_medication  sbp_multiplier  \
# 0     cat2                 no_treatment             1.0
# 1     cat2                 no_treatment             1.0
# 2     cat2  one_drug_half_dose_efficacy             1.0
# 3     cat2                 no_treatment             1.0
# 4     cat2                 no_treatment             1.0
#
#    ldlc_medication_adherence  polypill  sbp_medication_adherence  \
# 0                       cat3      cat2                      cat3
# 1                       cat3      cat2                      cat3
# 2                       cat3      cat2                      cat1
# 3                       cat1      cat2                      cat3
# 4                       cat1      cat2                      cat3
#
#     ldlc_medication ldlc_multiplier  visit_type  scheduled_date
# 0      no_treatment           1.000        none             NaT
# 1      no_treatment           1.000        none             NaT
# 2  medium_intensity           1.362        none             NaT
# 3      no_treatment           1.000        none             NaT
# 4      no_treatment           1.000        none             NaT
#
# [5 rows x 46 columns]

# %%
pop1 = pop0[['sex','alive','age']]

# %%
#pop0.columns

# %%
#sim.list_values()

# %%
data1 = pd.concat([pop1,
                   sim.get_value('high_body_mass_index_in_adults.propensity')(pop0.index).rename('bmi_propensity'),
                   sim.get_value('high_body_mass_index_in_adults.exposure')(pop0.index).rename('bmi_exposure'),
                  ], axis=1)
data1.head()
# Out:
#       sex  alive        age  bmi_propensity  bmi_exposure
# 0  Female  alive  47.388882        0.208828     23.564850
# 1    Male  alive  41.564194        0.358604     25.661107
# 2  Female  alive  53.155826        0.531571     34.110372
# 3    Male  alive  30.457692        0.388049     26.473747
# 4  Female  alive  19.554806        0.672873      5.000000

# %%
data1 = data1.loc[(data1.age > 25) & (data1.alive == 'alive')]

# %% [markdown]
# ## Adding RR and TMREL so I can find the individual RR for a Simulant
#
# Note that while this method will randomly generate data, I eventually need to match the RR's to the simulant for the specific draw. As HF has not been added yet, I am not sure I can do this currently.
#
# Also, we might just have the engineers add this to their initialization tasks instead!

# %%
def get_lognorm_from_quantiles(median: float, lower: float, upper: float,
                               quantiles: Tuple[float, float] = (0.025, 0.975)) -> sp.lognorm:
    mu = np.log(median)
    stdnorm_quantiles = sp.norm.ppf(quantiles)
    norm_quantiles = np.log([lower, upper])
    sigma = (norm_quantiles[1] - norm_quantiles[0]) / (stdnorm_quantiles[1] - stdnorm_quantiles[0])
    return sp.lognorm(s=sigma, scale=median)

# %%
test2 = get_lognorm_from_quantiles(1.14,1.12,1.16).rvs(size=len(data1))

# %%
data1['RR'] = test2
data1.head()
# Out:
#       sex  alive        age  bmi_propensity  bmi_exposure        RR
# 0  Female  alive  47.388882        0.208828     23.564850  1.128200
# 1    Male  alive  41.564194        0.358604     25.661107  1.158464
# 2  Female  alive  53.155826        0.531571     34.110372  1.147754
# 3    Male  alive  30.457692        0.388049     26.473747  1.123268
# 6    Male  alive  33.645113        0.199137     22.520013  1.148181

# %%
np.random.seed(123)
test3 = np.random.uniform(20,25,len(data1))
test3
# Out:
# array([23.48234593, 21.43069667, 21.13425727, ..., 23.09954019,
#        24.65176124, 22.11263259])

# %%
data1['TMREL'] = test3
data1.head()
# Out:
#       sex  alive        age  bmi_propensity  bmi_exposure        RR      TMREL
# 0  Female  alive  47.388882        0.208828     23.564850  1.128200  23.482346
# 1    Male  alive  41.564194        0.358604     25.661107  1.158464  21.430697
# 2  Female  alive  53.155826        0.531571     34.110372  1.147754  21.134257
# 3    Male  alive  30.457692        0.388049     26.473747  1.123268  22.756574
# 6    Male  alive  33.645113        0.199137     22.520013  1.148181  23.597345

# %% [markdown]
# ## Finding the individual simulant's RR and PAF

# %%
max((data1['bmi_exposure'].iloc[4] - data1['TMREL'].iloc[4]),0)

max((data1['bmi_exposure'] - data1['TMREL']),0)
# Out:
# 0

# %%
for i in range(len(data1)):
    data1['sim_RR'].iloc[i] = data1['RR'].iloc[i]**[max((data1['bmi_exposure'].iloc[i] - data1['TMREL'].iloc[i]),0)]
data1
# Out:
# /tmp/ipykernel_2756657/1010717381.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['sim_RR'].iloc[i] = data1['RR'].iloc[i]**[max((data1['bmi_exposure'].iloc[i] - data1['TMREL'].iloc[i]),0)]
#          sex  alive        age  bmi_propensity  bmi_exposure        RR  \
# 0     Female  alive  47.388882        0.208828     23.564850  1.128200
# 1       Male  alive  41.564194        0.358604     25.661107  1.158464
# 2     Female  alive  53.155826        0.531571     34.110372  1.147754
# 3       Male  alive  30.457692        0.388049     26.473747  1.123268
# 6       Male  alive  33.645113        0.199137     22.520013  1.148181
# ...      ...    ...        ...             ...           ...       ...
# 9994    Male  alive  82.973183        0.491704     26.062478  1.129068
# 9995  Female  alive  31.875800        0.356089     27.354193  1.138290
# 9996    Male  alive  69.906989        0.013521     19.319172  1.139587
# 9998  Female  alive  77.277694        0.623941     31.170490  1.149427
# 9999    Male  alive  27.612002        0.011760      7.176115  1.124033
#
#           TMREL    sim_RR
# 0     23.482346  1.010002
# 1     21.430697  1.863158
# 2     21.134257  5.978698
# 3     22.756574  1.540477
# 6     23.597345  1.000000
# ...         ...       ...
# 9994  22.670537  1.509466
# 9995  20.679220  2.374038
# 9996  23.099540  1.000000
# 9998  24.651761  2.478911
# 9999  22.112633  1.000000
#
# [7448 rows x 8 columns]

# %%
data1['PAF'] = (data1['sim_RR'] - 1) / data1['sim_RR']
data1
# Out:
#          sex  alive        age  bmi_propensity  bmi_exposure        RR  \
# 0     Female  alive  47.388882        0.208828     23.564850  1.128200
# 1       Male  alive  41.564194        0.358604     25.661107  1.158464
# 2     Female  alive  53.155826        0.531571     34.110372  1.147754
# 3       Male  alive  30.457692        0.388049     26.473747  1.123268
# 6       Male  alive  33.645113        0.199137     22.520013  1.148181
# ...      ...    ...        ...             ...           ...       ...
# 9994    Male  alive  82.973183        0.491704     26.062478  1.129068
# 9995  Female  alive  31.875800        0.356089     27.354193  1.138290
# 9996    Male  alive  69.906989        0.013521     19.319172  1.139587
# 9998  Female  alive  77.277694        0.623941     31.170490  1.149427
# 9999    Male  alive  27.612002        0.011760      7.176115  1.124033
#
#           TMREL    sim_RR       PAF
# 0     23.482346  1.010002  0.009903
# 1     21.430697  1.863158  0.463277
# 2     21.134257  5.978698  0.832739
# 3     22.756574  1.540477  0.350850
# 6     23.597345  1.000000  0.000000
# ...         ...       ...       ...
# 9994  22.670537  1.509466  0.337514
# 9995  20.679220  2.374038  0.578777
# 9996  23.099540  1.000000  0.000000
# 9998  24.651761  2.478911  0.596597
# 9999  22.112633  1.000000  0.000000
#
# [7448 rows x 9 columns]
